# %%
import os
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
cd /content/drive/MyDrive/Github
# Out:
# /content/drive/MyDrive/Github

# %%
# !git remote remove origin

# %%
# !git remote add origin https://AnYeHyeon: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@github.com/AnYeHyeon/DataScience2023.git

# %%
# !git remote -v
# Out:
# origin	https://AnYeHyeon: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@github.com/AnYeHyeon/DataScience2023.git (fetch)
# origin	https://AnYeHyeon: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@github.com/AnYeHyeon/DataScience2023.git (push)

# %%
cd /content/drive/MyDrive/Github/DataScience2023
# Out:
# /content/drive/MyDrive/Github/DataScience2023

# %%
# !git config --global user.email 'ahnyh4756@gmail.com'
# !git config --global user.name 'AnYeHyeon'

# %%
# !git add -A
# !git commit -m "Connect Google Colab and Drive"
# Out:
# [main bbbb31d] Connect Google Colab and Drive
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite "2_1_\341\204\211\341\205\245\341\206\253\341\204\222\341\205\247\341\206\274\341\204\222\341\205\254\341\204\200\341\205\261.ipynb" (98%)

# %%
# !git push -u origin main
# Out:
# remote: Invalid username or password.
# fatal: Authentication failed for 'https://github.com/AnYeHyeon/DataScience2023.git/'

# %% [markdown]
# # 가상데이터 만들기

# %%
import numpy as np

# %%
# 맞춰야 하는 정답
true_w = 2
true_b = -3

# %%
# 평균이 0이고 표준편차가 1인 정규분포로부터
# 50개의 데이터를 무작위로 추출
X = np.random.normal(1, size=50)
X
# Out:
# array([ 1.79296345,  1.57300578,  2.16979373,  1.58073711,  1.60833876,
#         0.16211865, -0.04542174,  1.39595558,  2.26013331, -0.23807603,
#         1.13578761,  2.78247475,  1.19455609,  1.97918447,  0.18360617,
#         0.59786005,  1.07526162,  0.29482638,  2.07468346, -0.83351425,
#         1.70607349,  0.43073685,  2.48590787, -0.10953866,  0.66725315,
#         0.7771734 ,  2.50650543,  1.64895964,  3.99211012,  0.13000155,
#         0.24135089,  2.22043511,  1.29608315,  1.42662175,  0.78967913,
#         1.31734217,  3.43832553,  0.27499971,  0.97836713, -0.65131494,
#         1.76079479,  1.48147759,  0.64386036, -0.26208456,  0.88281089,
#         0.61105578,  2.72336728,  0.21814338,  2.80138298,  2.15283959])

# %%
# y는 다음과 같은 관계식에 의해 얻어졌다. (가정)
y = true_w*X + true_b # y는 2X-3
y
# Out:
# array([ 0.58592689,  0.14601156,  1.33958745,  0.16147423,  0.21667752,
#        -2.67576271, -3.09084349, -0.20808884,  1.52026663, -3.47615205,
#        -0.72842478,  2.56494949, -0.61088781,  0.95836893, -2.63278767,
#        -1.80427991, -0.84947677, -2.41034723,  1.14936691, -4.66702851,
#         0.41214699, -2.13852631,  1.97181573, -3.21907732, -1.6654937 ,
#        -1.4456532 ,  2.01301085,  0.29791927,  4.98422023, -2.73999691,
#        -2.51729822,  1.44087022, -0.40783371, -0.14675651, -1.42064174,
#        -0.36531567,  3.87665107, -2.45000059, -1.04326575, -4.30262988,
#         0.52158957, -0.03704482, -1.71227929, -3.52416911, -1.23437823,
#        -1.77788844,  2.44673455, -2.56371325,  2.60276596,  1.30567917])

# %%
import matplotlib.pyplot as plt
plt.scatter(X, y)

# %%
# noise
noise = np.random.normal(0.1, size=50)
noise
# Out:
# array([-0.56825602,  1.43704117,  0.51361799,  0.29083528,  0.88188715,
#         0.11271762, -0.05709306,  0.08829582,  1.13357036,  1.54047245,
#        -0.69106762, -0.15990107, -1.27469814,  0.90207702,  0.17789526,
#         0.30065115, -0.62274002, -0.84132605,  0.13352416, -1.17531507,
#         2.12202775,  0.717437  ,  0.36633771,  0.36071313, -0.56013593,
#         0.23217328, -1.89903393,  1.69344765,  1.42658194,  1.50415518,
#         0.59657557,  0.9106254 ,  2.64727768,  0.20507856, -0.61590657,
#        -1.27599019,  0.68826549, -1.32623351, -0.49665016,  0.62158928,
#         0.86899148, -0.13495283, -0.34281859, -0.41668026,  0.40942169,
#         1.15159102, -0.04257314, -1.82127902,  0.93509896,  3.21944402])

# %%
y = y + noise

# %%
y
# Out:
# array([ 0.01767087,  1.58305273,  1.85320544,  0.45230951,  1.09856467,
#        -2.56304508, -3.14793655, -0.11979302,  2.65383698, -1.9356796 ,
#        -1.4194924 ,  2.40504842, -1.88558595,  1.86044596, -2.4548924 ,
#        -1.50362876, -1.47221679, -3.25167328,  1.28289107, -5.84234357,
#         2.53417474, -1.42108931,  2.33815344, -2.85836418, -2.22562962,
#        -1.21347992,  0.11397692,  1.99136693,  6.41080217, -1.23584173,
#        -1.92072265,  2.35149562,  2.23944397,  0.05832205, -2.03654831,
#        -1.64130586,  4.56491655, -3.7762341 , -1.53991591, -3.6810406 ,
#         1.39058105, -0.17199766, -2.05509787, -3.94084938, -0.82495654,
#        -0.62629742,  2.40416142, -4.38499226,  3.53786492,  4.52512319])

# %%
plt.scatter(X, y)
