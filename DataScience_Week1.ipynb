# %%
import os
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# !git clone https://AnYeHyeon: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@github.com/AnYeHyeon/DataScience2023.git
# !git config --global user.email 'ahnyh4756@gmail.com'
# !git config --global user.name 'AnYeHyeon'
# !git add DataScience_Week1.ipynb
# !git commit -m "Connect Google Colab and Drive"
# Out:
# fatal: destination path 'DataScience2023' already exists and is not an empty directory.
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git

# %%
cd /content/drive/MyDrive/Github/DataScience2023
# Out:
# /content/drive/MyDrive/Github/DataScience2023

# %%
# !git config --global user.email 'ahnyh4756@gmail.com'
# !git config --global user.name 'YeHyeon'

# %%
# !git remote remove origin
# !git remote add origin https://AnYeHyeon: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@github.com/AnYeHyeon/DataScience2023.git

# %%
# !git remote add origin git@github.com:AnYeHyeon/DataScience2023.git

# !git add DataScience_Week1.ipynb

# %%
# !git commit -m "Connect Google Colab and Drive"
# !git push -u origin main
# Out:
# [main f837956] Connect Google Colab and Drive
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite DataScience_Week1.ipynb (91%)
# remote: Invalid username or password.
# fatal: Authentication failed for 'https://github.com/AnYeHyeon/DataScience2023.git/'

# %%
import pandas as pd

# %%
# coamma seperated value
df = pd.read_csv('https://raw.githubusercontent.com/AnYeHyeon/DataScience_2023S/master/data/heart.csv')

# %%
df
# Out:
#      Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  \
# 0     63    1       typical     145   233    1        2    150      0
# 1     67    1  asymptomatic     160   286    0        2    108      1
# 2     67    1  asymptomatic     120   229    0        2    129      1
# 3     37    1    nonanginal     130   250    0        0    187      0
# 4     41    0    nontypical     130   204    0        2    172      0
# ..   ...  ...           ...     ...   ...  ...      ...    ...    ...
# 298   45    1       typical     110   264    0        0    132      0
# 299   68    1  asymptomatic     144   193    1        0    141      0
# 300   57    1  asymptomatic     130   131    0        0    115      1
# 301   57    0    nontypical     130   236    0        2    174      0
# 302   38    1    nonanginal     138   175    0        0    173      0
#
#      Oldpeak  Slope   Ca        Thal  AHD
# 0        2.3      3  0.0       fixed   No
# ...

# %%
df.describe() # 기초통계량
# Out:
#               Age         Sex      RestBP        Chol         Fbs     RestECG  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.438944    0.679868  131.689769  246.693069    0.148515    0.990099
# std      9.038662    0.467299   17.599748   51.776918    0.356198    0.994971
# min     29.000000    0.000000   94.000000  126.000000    0.000000    0.000000
# 25%     48.000000    0.000000  120.000000  211.000000    0.000000    0.000000
# 50%     56.000000    1.000000  130.000000  241.000000    0.000000    1.000000
# 75%     61.000000    1.000000  140.000000  275.000000    0.000000    2.000000
# max     77.000000    1.000000  200.000000  564.000000    1.000000    2.000000
#
#             MaxHR       ExAng     Oldpeak       Slope          Ca
# count  303.000000  303.000000  303.000000  303.000000  299.000000
# mean   149.607261    0.326733    1.039604    1.600660    0.672241
# std     22.875003    0.469794    1.161075    0.616226    0.937438
# ...

# %%
df.head()
df.tail()
# Out:
#      Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  \
# 298   45    1       typical     110   264    0        0    132      0
# 299   68    1  asymptomatic     144   193    1        0    141      0
# 300   57    1  asymptomatic     130   131    0        0    115      1
# 301   57    0    nontypical     130   236    0        2    174      0
# 302   38    1    nonanginal     138   175    0        0    173      0
#
#      Oldpeak  Slope   Ca        Thal  AHD
# 298      1.2      2  0.0  reversable  Yes
# 299      3.4      2  2.0  reversable  Yes
# 300      1.2      2  1.0  reversable  Yes
# 301      0.0      2  1.0      normal  Yes
# 302      0.0      1  NaN      normal   No

# %%
df.T # 행열이 바뀜
# Out:
#                0             1             2           3           4    \
# Age             63            67            67          37          41
# Sex              1             1             1           1           0
# ChestPain  typical  asymptomatic  asymptomatic  nonanginal  nontypical
# RestBP         145           160           120         130         130
# Chol           233           286           229         250         204
# Fbs              1             0             0           0           0
# RestECG          2             2             2           0           2
# MaxHR          150           108           129         187         172
# ExAng            0             1             1           0           0
# Oldpeak        2.3           1.5           2.6         3.5         1.4
# Slope            3             2             2           3           1
# Ca             0.0           3.0           2.0         0.0         0.0
# ...

# %%
df['Age']
# Out:
# 0      63
# 1      67
# 2      67
# 3      37
# 4      41
#        ..
# 298    45
# 299    68
# 300    57
# 301    57
# 302    38
# Name: Age, Length: 303, dtype: int64

# %%
# 복수의 열선택
df[['Age', 'Sex']]
# Out:
#      Age  Sex
# 0     63    1
# 1     67    1
# 2     67    1
# 3     37    1
# 4     41    0
# ..   ...  ...
# 298   45    1
# 299   68    1
# 300   57    1
# 301   57    0
# 302   38    1
#
# [303 rows x 2 columns]

# %%
columns = df.columns

# %%
df[columns[:5]]
# Out:
#      Age  Sex     ChestPain  RestBP  Chol
# 0     63    1       typical     145   233
# 1     67    1  asymptomatic     160   286
# 2     67    1  asymptomatic     120   229
# 3     37    1    nonanginal     130   250
# 4     41    0    nontypical     130   204
# ..   ...  ...           ...     ...   ...
# 298   45    1       typical     110   264
# 299   68    1  asymptomatic     144   193
# 300   57    1  asymptomatic     130   131
# 301   57    0    nontypical     130   236
# 302   38    1    nonanginal     138   175
#
# [303 rows x 5 columns]

# %%
df[[i for i in columns if i.startswith('C')]]
# Out:
#         ChestPain  Chol   Ca
# 0         typical   233  0.0
# 1    asymptomatic   286  3.0
# 2    asymptomatic   229  2.0
# 3      nonanginal   250  0.0
# 4      nontypical   204  0.0
# ..            ...   ...  ...
# 298       typical   264  0.0
# 299  asymptomatic   193  2.0
# 300  asymptomatic   131  1.0
# 301    nontypical   236  1.0
# 302    nonanginal   175  NaN
#
# [303 rows x 3 columns]

# %% [markdown]
# # 연습문제 Auto.csv

# %% [markdown]
# # 그래프 그리기
# ## matplotlib
# - line plot
# - Scatter plot
# - Histogram

# %%
import matplotlib.pyplot as plt

# %%
# 1. 선형그래프
x = [1,2,3,3.5,4,5]
plt.plot(x)

# %%
x = [1,2,3,4,5]
x2 = [2,4,6,8,10]

# %%
plt.plot(x)
plt.plot(x2)
plt.xlabel("x")
plt.ylabel("y")
# Out:
# Text(0, 0.5, 'y')

# %%
# scatter (산점도)
df.head()
# Out:
#    Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  Oldpeak  \
# 0   63    1       typical     145   233    1        2    150      0      2.3
# 1   67    1  asymptomatic     160   286    0        2    108      1      1.5
# 2   67    1  asymptomatic     120   229    0        2    129      1      2.6
# 3   37    1    nonanginal     130   250    0        0    187      0      3.5
# 4   41    0    nontypical     130   204    0        2    172      0      1.4
#
#    Slope   Ca        Thal  AHD
# 0      3  0.0       fixed   No
# 1      2  3.0      normal  Yes
# 2      2  2.0  reversable  Yes
# 3      3  0.0      normal   No
# 4      1  0.0      normal   No

# %%
age = df['Age']
bp = df['RestBP']

# %%
plt.scatter(age, bp)

# %%
plt.scatter(df['Sex'], bp)

# %%
# histogram
plt.hist(df['Age'])
# Out:
# (array([ 1., 10., 33., 38., 37., 60., 64., 43., 14.,  3.]),
#  array([29. , 33.8, 38.6, 43.4, 48.2, 53. , 57.8, 62.6, 67.4, 72.2, 77. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['Age'], bins=20)
# Out:
# (array([ 1.,  0.,  6.,  4.,  7., 26., 19., 19., 12., 25., 32., 28., 45.,
#         19., 19., 24.,  7.,  7.,  1.,  2.]),
#  array([29. , 31.4, 33.8, 36.2, 38.6, 41. , 43.4, 45.8, 48.2, 50.6, 53. ,
#         55.4, 57.8, 60.2, 62.6, 65. , 67.4, 69.8, 72.2, 74.6, 77. ]),
#  <BarContainer object of 20 artists>)

# %%
# coamma seperated value
df = pd.read_csv('https://raw.githubusercontent.com/AnYeHyeon/DataScience_2023S/master/data/datacleaning.csv')

# %%
df
# Out:
#     Duration  Pulse  Maxpulse  Calories
# 0         60  117.0       145     479.0
# 1         60  103.0       135     340.0
# 2         45  109.0       175     282.4
# 3         45    NaN       148     406.0
# 4         60  100.0       120     250.7
# 5        450  104.0       134     253.3
# 6         30  109.0       133     195.1
# 7         60    NaN       124     269.0
# 8         60  103.0       147     329.3
# 9         60  100.0       120     250.7
# 10        60  100.0       120     250.7
# 11        60   98.0       120     215.2
# 12        45   90.0       112       NaN
# 13        60  103.0       123     323.0
# 14        60  100.0       120     250.7
# 15        45    NaN       132     246.0
# 16        60  102.0       126     334.5
# 17        60  100.0       120     250.0
# 18        60  103.0       132       NaN
